# %%
# =============================================================================
# Created By:     Kai Metzger
# Created School: Franz-Oberthuer-Schule Wuerzburg
# Created Email:  metzgerkai@franz-oberthuer-schule.de
# Created Date:   Fri December 06 18:08 UTC 2024
# Version:        1.0
# =============================================================================
"""The Module has been build for training the symbols dataset with images + 
ground truth on a Raspberry Pi 5 with a standard USB camera. An image with a 
resolution of 640px x 480px can be recorded with the Python script 
create-symbols-dataset.py.
The files in the dataset <2023 symbols> should be ordered in the following
manner:             > explanation
- 2023 symbols      
  - dataset3        > dataset version (dataset1 - 3 where used in the project)
    - data          > images (.png files)
    - gt            > ground truth (.txt files with class labels 1-4)
"""

# =============================================================================
# Imports
# =============================================================================

# Importieren von Bibliotheken
import cv2
import os
import numpy as np
from tensorflow.keras import layers, models, utils, callbacks
import matplotlib.pyplot as plt

# To get reproducable results with the same training
np.random.seed(42)

# %%
# =============================================================================
# Declare variables
# =============================================================================
img_size_x = 32
img_size_y = 24
img_dim = img_size_x * img_size_y

# Change <dataset name> to your dataset
img_dir = '/home/pi/images/<dataset name>/data'
gt_dir = '/home/pi/images/<dataset name>/gt'
checkpoint_filepath = '/home/pi/images/<dataset name>/chpt'

# %%
# =============================================================================
# Get number of data (image/label) 
# =============================================================================
anz_data = len(os.listdir(img_dir))
anz_data = int(anz_data)
dataset = np.zeros((anz_data, img_size_x, img_size_y), dtype=float)
ground_truth = np.zeros((anz_data), dtype=int)
print("dataset size:", anz_data)
# Out:
# dataset size: 440

# %%
# =============================================================================
# Define functions
# =============================================================================
# Change image size and convert to grayscale images
def pic_prep (image, x, y):
  image = cv2.resize(image, (y,x))                # change image size
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # convert to grayscale
  image = image / 255                             # image normalization
  return image

# Shuffle images
def unison_shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %%
# =============================================================================
# Callback for training
# =============================================================================
# Set verbose flag to 0 to omit loss/accuracy output per epoch
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath + ".keras",
    save_weights_only=False,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=True,
    verbose = 1)

# %%
# =============================================================================
# Read dataset
# =============================================================================
for i in range(0, anz_data, 1):
    img_name = img_dir + '/' + str(i) + '.png'      # create file names
    image = cv2.imread(img_name)                    # read image
    image = pic_prep(image, img_size_x, img_size_y) # prepare image
    dataset[i,:,:] = image                          # 2d-image to 3d-array
    
    txt_name = gt_dir + '/' + str(i) + '.txt'       # create gt file names
    txt_inhalt = np.genfromtxt(txt_name, delimiter=',') #ziffer in Truth schreiben
    ground_truth[i] = txt_inhalt
#print(ground_truth)

# %%
# =============================================================================
# Prepare dataset: train set (80%) and test set (20%)
# =============================================================================
dataset = dataset.reshape(anz_data, img_dim) # convert into 2d array (all pixel in one row)
ground_truth = ground_truth.reshape(anz_data, 1)

dataset, ground_truth = unison_shuffle(dataset, ground_truth)

trainset = np.random.choice(dataset.shape[0],
                            int(dataset.shape[0]*0.80), 
                            replace=False)
train_data = dataset[trainset,:]
train_gt = ground_truth[trainset]
train_gt = utils.to_categorical(train_gt, 4)

testset = np.delete(np.arange(0, len(ground_truth) ), 
                    trainset) 
test_data = dataset[testset,:]
test_gt = ground_truth[testset]
test_gt = utils.to_categorical(test_gt, 4)

#print(ground_truth)
#print(dataset)
#print(trainset)
#print(train_data)
#print(train_gt)

# %%
# =============================================================================
# Create neural network with 4 layers and (64, 32, 16, 4) neurons per layer.
# =============================================================================
model = models.Sequential()
model.add(layers.Dense(64,input_dim=img_dim,activation='relu'))
model.add(layers.Dense(32,activation='relu'))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(4,activation='sigmoid'))
model.compile(loss='mean_squared_error', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
# =============================================================================
# Train the neuronal network e.g. for 300 epochs.
# =============================================================================
history = model.fit(train_data, 
                    train_gt, 
                    batch_size=4, 
                    epochs=300, 
                    verbose=0, 
                    shuffle=True, 
                    validation_data=(test_data, test_gt), 
                    callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.26136, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 2: val_accuracy improved from 0.26136 to 0.28409, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 3: val_accuracy did not improve from 0.28409
#
# Epoch 4: val_accuracy did not improve from 0.28409
#
# Epoch 5: val_accuracy did not improve from 0.28409
#
# Epoch 6: val_accuracy did not improve from 0.28409
#
# Epoch 7: val_accuracy did not improve from 0.28409
#
# Epoch 8: val_accuracy did not improve from 0.28409
#
# Epoch 9: val_accuracy did not improve from 0.28409
#
# Epoch 10: val_accuracy did not improve from 0.28409
#
# Epoch 11: val_accuracy did not improve from 0.28409
#
# Epoch 12: val_accuracy did not improve from 0.28409
#
# Epoch 13: val_accuracy improved from 0.28409 to 0.30682, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 14: val_accuracy did not improve from 0.30682
#
# Epoch 15: val_accuracy did not improve from 0.30682
#
# Epoch 16: val_accuracy improved from 0.30682 to 0.32955, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 17: val_accuracy did not improve from 0.32955
#
# Epoch 18: val_accuracy did not improve from 0.32955
#
# Epoch 19: val_accuracy did not improve from 0.32955
#
# Epoch 20: val_accuracy improved from 0.32955 to 0.38636, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 21: val_accuracy did not improve from 0.38636
#
# Epoch 22: val_accuracy did not improve from 0.38636
#
# Epoch 23: val_accuracy did not improve from 0.38636
#
# Epoch 24: val_accuracy did not improve from 0.38636
#
# Epoch 25: val_accuracy did not improve from 0.38636
#
# Epoch 26: val_accuracy did not improve from 0.38636
#
# Epoch 27: val_accuracy did not improve from 0.38636
#
# Epoch 28: val_accuracy did not improve from 0.38636
#
# Epoch 29: val_accuracy did not improve from 0.38636
#
# Epoch 30: val_accuracy did not improve from 0.38636
#
# Epoch 31: val_accuracy did not improve from 0.38636
#
# Epoch 32: val_accuracy did not improve from 0.38636
#
# Epoch 33: val_accuracy did not improve from 0.38636
#
# Epoch 34: val_accuracy did not improve from 0.38636
#
# Epoch 35: val_accuracy did not improve from 0.38636
#
# Epoch 36: val_accuracy did not improve from 0.38636
#
# Epoch 37: val_accuracy did not improve from 0.38636
#
# Epoch 38: val_accuracy did not improve from 0.38636
#
# Epoch 39: val_accuracy did not improve from 0.38636
#
# Epoch 40: val_accuracy did not improve from 0.38636
#
# Epoch 41: val_accuracy did not improve from 0.38636
#
# Epoch 42: val_accuracy did not improve from 0.38636
#
# Epoch 43: val_accuracy did not improve from 0.38636
#
# Epoch 44: val_accuracy did not improve from 0.38636
#
# Epoch 45: val_accuracy did not improve from 0.38636
#
# Epoch 46: val_accuracy did not improve from 0.38636
#
# Epoch 47: val_accuracy did not improve from 0.38636
#
# Epoch 48: val_accuracy did not improve from 0.38636
#
# Epoch 49: val_accuracy improved from 0.38636 to 0.39773, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 50: val_accuracy improved from 0.39773 to 0.43182, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 51: val_accuracy did not improve from 0.43182
#
# Epoch 52: val_accuracy did not improve from 0.43182
#
# Epoch 53: val_accuracy did not improve from 0.43182
#
# Epoch 54: val_accuracy did not improve from 0.43182
#
# Epoch 55: val_accuracy did not improve from 0.43182
#
# Epoch 56: val_accuracy did not improve from 0.43182
#
# Epoch 57: val_accuracy did not improve from 0.43182
#
# Epoch 58: val_accuracy did not improve from 0.43182
#
# Epoch 59: val_accuracy improved from 0.43182 to 0.44318, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 60: val_accuracy did not improve from 0.44318
#
# Epoch 61: val_accuracy did not improve from 0.44318
#
# Epoch 62: val_accuracy did not improve from 0.44318
#
# Epoch 63: val_accuracy did not improve from 0.44318
#
# Epoch 64: val_accuracy did not improve from 0.44318
#
# Epoch 65: val_accuracy did not improve from 0.44318
#
# Epoch 66: val_accuracy did not improve from 0.44318
#
# Epoch 67: val_accuracy improved from 0.44318 to 0.45455, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 68: val_accuracy did not improve from 0.45455
#
# Epoch 69: val_accuracy did not improve from 0.45455
#
# Epoch 70: val_accuracy did not improve from 0.45455
#
# Epoch 71: val_accuracy did not improve from 0.45455
#
# Epoch 72: val_accuracy improved from 0.45455 to 0.46591, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 73: val_accuracy did not improve from 0.46591
#
# Epoch 74: val_accuracy did not improve from 0.46591
#
# Epoch 75: val_accuracy improved from 0.46591 to 0.48864, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 76: val_accuracy did not improve from 0.48864
#
# Epoch 77: val_accuracy did not improve from 0.48864
#
# Epoch 78: val_accuracy did not improve from 0.48864
#
# Epoch 79: val_accuracy did not improve from 0.48864
#
# Epoch 80: val_accuracy did not improve from 0.48864
#
# Epoch 81: val_accuracy did not improve from 0.48864
#
# Epoch 82: val_accuracy did not improve from 0.48864
#
# Epoch 83: val_accuracy did not improve from 0.48864
#
# Epoch 84: val_accuracy did not improve from 0.48864
#
# Epoch 85: val_accuracy did not improve from 0.48864
#
# Epoch 86: val_accuracy did not improve from 0.48864
#
# Epoch 87: val_accuracy did not improve from 0.48864
#
# Epoch 88: val_accuracy did not improve from 0.48864
#
# Epoch 89: val_accuracy did not improve from 0.48864
#
# Epoch 90: val_accuracy did not improve from 0.48864
#
# Epoch 91: val_accuracy did not improve from 0.48864
#
# Epoch 92: val_accuracy did not improve from 0.48864
#
# Epoch 93: val_accuracy did not improve from 0.48864
#
# Epoch 94: val_accuracy did not improve from 0.48864
#
# Epoch 95: val_accuracy did not improve from 0.48864
#
# Epoch 96: val_accuracy did not improve from 0.48864
#
# Epoch 97: val_accuracy did not improve from 0.48864
#
# Epoch 98: val_accuracy did not improve from 0.48864
#
# Epoch 99: val_accuracy did not improve from 0.48864
#
# Epoch 100: val_accuracy did not improve from 0.48864
#
# Epoch 101: val_accuracy did not improve from 0.48864
#
# Epoch 102: val_accuracy did not improve from 0.48864
#
# Epoch 103: val_accuracy did not improve from 0.48864
#
# Epoch 104: val_accuracy did not improve from 0.48864
#
# Epoch 105: val_accuracy did not improve from 0.48864
#
# Epoch 106: val_accuracy did not improve from 0.48864
#
# Epoch 107: val_accuracy did not improve from 0.48864
#
# Epoch 108: val_accuracy did not improve from 0.48864
#
# Epoch 109: val_accuracy did not improve from 0.48864
#
# Epoch 110: val_accuracy did not improve from 0.48864
#
# Epoch 111: val_accuracy did not improve from 0.48864
#
# Epoch 112: val_accuracy did not improve from 0.48864
#
# Epoch 113: val_accuracy did not improve from 0.48864
#
# Epoch 114: val_accuracy did not improve from 0.48864
#
# Epoch 115: val_accuracy did not improve from 0.48864
#
# Epoch 116: val_accuracy did not improve from 0.48864
#
# Epoch 117: val_accuracy did not improve from 0.48864
#
# Epoch 118: val_accuracy did not improve from 0.48864
#
# Epoch 119: val_accuracy did not improve from 0.48864
#
# Epoch 120: val_accuracy did not improve from 0.48864
#
# Epoch 121: val_accuracy did not improve from 0.48864
#
# Epoch 122: val_accuracy did not improve from 0.48864
#
# Epoch 123: val_accuracy did not improve from 0.48864
#
# Epoch 124: val_accuracy did not improve from 0.48864
#
# Epoch 125: val_accuracy did not improve from 0.48864
#
# Epoch 126: val_accuracy did not improve from 0.48864
#
# Epoch 127: val_accuracy did not improve from 0.48864
#
# Epoch 128: val_accuracy did not improve from 0.48864
#
# Epoch 129: val_accuracy did not improve from 0.48864
#
# Epoch 130: val_accuracy did not improve from 0.48864
#
# Epoch 131: val_accuracy did not improve from 0.48864
#
# Epoch 132: val_accuracy did not improve from 0.48864
#
# Epoch 133: val_accuracy did not improve from 0.48864
#
# Epoch 134: val_accuracy did not improve from 0.48864
#
# Epoch 135: val_accuracy did not improve from 0.48864
#
# Epoch 136: val_accuracy did not improve from 0.48864
#
# Epoch 137: val_accuracy did not improve from 0.48864
#
# Epoch 138: val_accuracy did not improve from 0.48864
#
# Epoch 139: val_accuracy did not improve from 0.48864
#
# Epoch 140: val_accuracy did not improve from 0.48864
#
# Epoch 141: val_accuracy did not improve from 0.48864
#
# Epoch 142: val_accuracy did not improve from 0.48864
#
# Epoch 143: val_accuracy did not improve from 0.48864
#
# Epoch 144: val_accuracy did not improve from 0.48864
#
# Epoch 145: val_accuracy did not improve from 0.48864
#
# Epoch 146: val_accuracy did not improve from 0.48864
#
# Epoch 147: val_accuracy did not improve from 0.48864
#
# Epoch 148: val_accuracy did not improve from 0.48864
#
# Epoch 149: val_accuracy did not improve from 0.48864
#
# Epoch 150: val_accuracy did not improve from 0.48864
#
# Epoch 151: val_accuracy did not improve from 0.48864
#
# Epoch 152: val_accuracy did not improve from 0.48864
#
# Epoch 153: val_accuracy did not improve from 0.48864
#
# Epoch 154: val_accuracy did not improve from 0.48864
#
# Epoch 155: val_accuracy did not improve from 0.48864
#
# Epoch 156: val_accuracy did not improve from 0.48864
#
# Epoch 157: val_accuracy did not improve from 0.48864
#
# Epoch 158: val_accuracy did not improve from 0.48864
#
# Epoch 159: val_accuracy did not improve from 0.48864
#
# Epoch 160: val_accuracy did not improve from 0.48864
#
# Epoch 161: val_accuracy improved from 0.48864 to 0.50000, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 162: val_accuracy did not improve from 0.50000
#
# Epoch 163: val_accuracy did not improve from 0.50000
#
# Epoch 164: val_accuracy did not improve from 0.50000
#
# Epoch 165: val_accuracy did not improve from 0.50000
#
# Epoch 166: val_accuracy did not improve from 0.50000
#
# Epoch 167: val_accuracy did not improve from 0.50000
#
# Epoch 168: val_accuracy did not improve from 0.50000
#
# Epoch 169: val_accuracy did not improve from 0.50000
#
# Epoch 170: val_accuracy did not improve from 0.50000
#
# Epoch 171: val_accuracy did not improve from 0.50000
#
# Epoch 172: val_accuracy did not improve from 0.50000
#
# Epoch 173: val_accuracy did not improve from 0.50000
#
# Epoch 174: val_accuracy did not improve from 0.50000
#
# Epoch 175: val_accuracy did not improve from 0.50000
#
# Epoch 176: val_accuracy did not improve from 0.50000
#
# Epoch 177: val_accuracy did not improve from 0.50000
#
# Epoch 178: val_accuracy did not improve from 0.50000
#
# Epoch 179: val_accuracy did not improve from 0.50000
#
# Epoch 180: val_accuracy did not improve from 0.50000
#
# Epoch 181: val_accuracy did not improve from 0.50000
#
# Epoch 182: val_accuracy did not improve from 0.50000
#
# Epoch 183: val_accuracy did not improve from 0.50000
#
# Epoch 184: val_accuracy did not improve from 0.50000
#
# Epoch 185: val_accuracy did not improve from 0.50000
#
# Epoch 186: val_accuracy did not improve from 0.50000
#
# Epoch 187: val_accuracy did not improve from 0.50000
#
# Epoch 188: val_accuracy did not improve from 0.50000
#
# Epoch 189: val_accuracy did not improve from 0.50000
#
# Epoch 190: val_accuracy did not improve from 0.50000
#
# Epoch 191: val_accuracy did not improve from 0.50000
#
# Epoch 192: val_accuracy did not improve from 0.50000
#
# Epoch 193: val_accuracy did not improve from 0.50000
#
# Epoch 194: val_accuracy did not improve from 0.50000
#
# Epoch 195: val_accuracy did not improve from 0.50000
#
# Epoch 196: val_accuracy did not improve from 0.50000
#
# Epoch 197: val_accuracy did not improve from 0.50000
#
# Epoch 198: val_accuracy did not improve from 0.50000
#
# Epoch 199: val_accuracy did not improve from 0.50000
#
# Epoch 200: val_accuracy did not improve from 0.50000
#
# Epoch 201: val_accuracy did not improve from 0.50000
#
# Epoch 202: val_accuracy did not improve from 0.50000
#
# Epoch 203: val_accuracy did not improve from 0.50000
#
# Epoch 204: val_accuracy did not improve from 0.50000
#
# Epoch 205: val_accuracy did not improve from 0.50000
#
# Epoch 206: val_accuracy did not improve from 0.50000
#
# Epoch 207: val_accuracy did not improve from 0.50000
#
# Epoch 208: val_accuracy did not improve from 0.50000
#
# Epoch 209: val_accuracy did not improve from 0.50000
#
# Epoch 210: val_accuracy did not improve from 0.50000
#
# Epoch 211: val_accuracy did not improve from 0.50000
#
# Epoch 212: val_accuracy did not improve from 0.50000
#
# Epoch 213: val_accuracy did not improve from 0.50000
#
# Epoch 214: val_accuracy did not improve from 0.50000
#
# Epoch 215: val_accuracy did not improve from 0.50000
#
# Epoch 216: val_accuracy did not improve from 0.50000
#
# Epoch 217: val_accuracy did not improve from 0.50000
#
# Epoch 218: val_accuracy did not improve from 0.50000
#
# Epoch 219: val_accuracy did not improve from 0.50000
#
# Epoch 220: val_accuracy did not improve from 0.50000
#
# Epoch 221: val_accuracy did not improve from 0.50000
#
# Epoch 222: val_accuracy did not improve from 0.50000
#
# Epoch 223: val_accuracy did not improve from 0.50000
#
# Epoch 224: val_accuracy did not improve from 0.50000
#
# Epoch 225: val_accuracy did not improve from 0.50000
#
# Epoch 226: val_accuracy did not improve from 0.50000
#
# Epoch 227: val_accuracy did not improve from 0.50000
#
# Epoch 228: val_accuracy did not improve from 0.50000
#
# Epoch 229: val_accuracy did not improve from 0.50000
#
# Epoch 230: val_accuracy did not improve from 0.50000
#
# Epoch 231: val_accuracy did not improve from 0.50000
#
# Epoch 232: val_accuracy did not improve from 0.50000
#
# Epoch 233: val_accuracy did not improve from 0.50000
#
# Epoch 234: val_accuracy did not improve from 0.50000
#
# Epoch 235: val_accuracy did not improve from 0.50000
#
# Epoch 236: val_accuracy did not improve from 0.50000
#
# Epoch 237: val_accuracy did not improve from 0.50000
#
# Epoch 238: val_accuracy did not improve from 0.50000
#
# Epoch 239: val_accuracy did not improve from 0.50000
#
# Epoch 240: val_accuracy did not improve from 0.50000
#
# Epoch 241: val_accuracy did not improve from 0.50000
#
# Epoch 242: val_accuracy did not improve from 0.50000
#
# Epoch 243: val_accuracy did not improve from 0.50000
#
# Epoch 244: val_accuracy did not improve from 0.50000
#
# Epoch 245: val_accuracy did not improve from 0.50000
#
# Epoch 246: val_accuracy did not improve from 0.50000
#
# Epoch 247: val_accuracy did not improve from 0.50000
#
# Epoch 248: val_accuracy did not improve from 0.50000
#
# Epoch 249: val_accuracy did not improve from 0.50000
#
# Epoch 250: val_accuracy did not improve from 0.50000
#
# Epoch 251: val_accuracy did not improve from 0.50000
#
# Epoch 252: val_accuracy did not improve from 0.50000
#
# Epoch 253: val_accuracy did not improve from 0.50000
#
# Epoch 254: val_accuracy did not improve from 0.50000
#
# Epoch 255: val_accuracy did not improve from 0.50000
#
# Epoch 256: val_accuracy did not improve from 0.50000
#
# Epoch 257: val_accuracy did not improve from 0.50000
#
# Epoch 258: val_accuracy did not improve from 0.50000
#
# Epoch 259: val_accuracy did not improve from 0.50000
#
# Epoch 260: val_accuracy did not improve from 0.50000
#
# Epoch 261: val_accuracy did not improve from 0.50000
#
# Epoch 262: val_accuracy did not improve from 0.50000
#
# Epoch 263: val_accuracy did not improve from 0.50000
#
# Epoch 264: val_accuracy did not improve from 0.50000
#
# Epoch 265: val_accuracy did not improve from 0.50000
#
# Epoch 266: val_accuracy did not improve from 0.50000
#
# Epoch 267: val_accuracy did not improve from 0.50000
#
# Epoch 268: val_accuracy did not improve from 0.50000
#
# Epoch 269: val_accuracy did not improve from 0.50000
#
# Epoch 270: val_accuracy did not improve from 0.50000
#
# Epoch 271: val_accuracy did not improve from 0.50000
#
# Epoch 272: val_accuracy did not improve from 0.50000
#
# Epoch 273: val_accuracy did not improve from 0.50000
#
# Epoch 274: val_accuracy did not improve from 0.50000
#
# Epoch 275: val_accuracy did not improve from 0.50000
#
# Epoch 276: val_accuracy did not improve from 0.50000
#
# Epoch 277: val_accuracy did not improve from 0.50000
#
# Epoch 278: val_accuracy did not improve from 0.50000
#
# Epoch 279: val_accuracy did not improve from 0.50000
#
# Epoch 280: val_accuracy did not improve from 0.50000
#
# Epoch 281: val_accuracy did not improve from 0.50000
#
# Epoch 282: val_accuracy did not improve from 0.50000
#
# Epoch 283: val_accuracy did not improve from 0.50000
#
# Epoch 284: val_accuracy did not improve from 0.50000
#
# Epoch 285: val_accuracy did not improve from 0.50000
#
# Epoch 286: val_accuracy did not improve from 0.50000
#
# Epoch 287: val_accuracy did not improve from 0.50000
#
# Epoch 288: val_accuracy did not improve from 0.50000
#
# Epoch 289: val_accuracy did not improve from 0.50000
#
# Epoch 290: val_accuracy did not improve from 0.50000
#
# Epoch 291: val_accuracy did not improve from 0.50000
#
# Epoch 292: val_accuracy did not improve from 0.50000
#
# Epoch 293: val_accuracy did not improve from 0.50000
#
# Epoch 294: val_accuracy did not improve from 0.50000
#
# Epoch 295: val_accuracy improved from 0.50000 to 0.51136, saving model to /home/pi/Documents/2023 symbols/dataset3/checkpoints.keras
#
# Epoch 296: val_accuracy did not improve from 0.51136
#
# Epoch 297: val_accuracy did not improve from 0.51136
#
# Epoch 298: val_accuracy did not improve from 0.51136
#
# Epoch 299: val_accuracy did not improve from 0.51136
#
# Epoch 300: val_accuracy did not improve from 0.51136

# %%
# =============================================================================
# Plot train and val accuracy.
# =============================================================================

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# =============================================================================
# Plot train and val loss.
# =============================================================================

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower left')
plt.show()

# %%
# =============================================================================
# Load pretrained dataset weights to e.g. test on new (unseen) data.
# =============================================================================
model.load_weights(checkpoint_filepath + ".keras")

# %%
# =============================================================================
# Test dataset on xxx.
# =============================================================================
score = model.evaluate(test_data, test_gt, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4940 - loss: 0.1763
# Test score: 0.17193414270877838
# Test accuracy: 0.5113636255264282

# %%
# =============================================================================
# Testing on a single image.
# =============================================================================
data_pred = np.zeros((1, img_size_x, img_size_y), dtype=float)
img_pred = cv2.imread('/home/pi/Documents/2023 symbols/dataset3/data/217.png')
img_pred = pic_prep(img_pred, img_size_x, img_size_y)
data_pred[0,:,:] = img_pred
data_pred = data_pred.reshape(1,img_dim)
result = model.predict(data_pred)
result = np.round(result, decimals=2)

print("Probability for class (Kreuz, Kreis, Dreieck, Viereck) in percent", 
      result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Probability for class (Kreuz, Kreis, Dreieck, Viereck) in percent [[0.   0.02 0.   0.98]]

# %%
# =============================================================================
# Output class: 
# translate class label (0,1,2,3) to class (Kreuz, Kreis, Dreieck, Viereck).
# =============================================================================

max_res = 0
res_index = 4
for i in range(0, 4, 1):
    if result[0,i] > max_res:
        max_res = result[0,i]
        res_index = i

if res_index == 0:
    print('Das ist ein Kreuz!')
elif res_index == 1:
    print('Das ist ein Kreis!')
elif res_index == 2:
    print('Das ist ein Dreieck!')
elif res_index == 3:
    print('Das ist ein Viereck!')
elif res_index == 4:
    print('Du hast einen Fehler in deinem Programm!')
# Out:
# Das ist ein Viereck!
