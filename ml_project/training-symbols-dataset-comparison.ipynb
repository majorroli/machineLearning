# %%
# =============================================================================
# Created By:     Roland Mayer
# Created School: Fos Bos Marktheidenfeld
# Created Email:  roland.mayyer@fosbos-marktheidenfeld.de
# Created Date:   Fri December 28 18:08 UTC 2024
# Version:        1.0
# =============================================================================
"""The Module has been build for training the symbols dataset with images + 
ground truth on a Raspberry Pi 5 with a standard USB camera. An image with a 
resolution of 640px x 480px can be recorded with the Python script 
create-symbols-dataset.py.
The files in the dataset <2023 symbols> should be ordered in the following
manner:             > explanation
- 2023 symbols      
  - dataset3        > dataset version (dataset1 - 3 where used in the project)
    - data          > images (.png files)
    - gt            > ground truth (.txt files with class labels 1-4)
"""

# =============================================================================
# Imports
# =============================================================================

# Importieren von Bibliotheken
import cv2
import os
import numpy as np
from tensorflow.keras import layers, models, utils, callbacks
import matplotlib.pyplot as plt

np.random.seed(42)

# Flags
plots_on = True
test_on_specific_image = False

# %%
# =============================================================================
# Define functions
# =============================================================================
# Change image size and convert to grayscale images
def pic_prep (image, x, y):
  image = cv2.resize(image, (y,x)) # change image size
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # convert to grayscale
  image = image / 255 # image normalization
  return image

# Shuffle images
def unison_shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# todo: only show output of training for every 10 epochs
# Add callback to only print loss etc. after e.g. 10 epochs:
# https://stackoverflow.com/questions/44931689/how-to-disable-printing-reports-after-each-epoch-in-keras
class callback_print(callbacks.Callback):
    SHOW_NUMBER = 10
    counter = 0
    epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch = epoch

    def on_train_batch_end(self, batch, logs=None):
        if self.counter == self.SHOW_NUMBER or self.epoch == 1:
            print('Epoch: ' + str(self.epoch) + ' loss: ' + str(logs['loss']))
            if self.epoch > 1:
                self.counter = 0
        self.counter += 1

# %%
# =============================================================================
# Declare variables
# =============================================================================
def train_symbols_model(num_training=0,
                        image_size=[32, 24], #
                        num_neurons_per_layer=[64,32,16,4],
                        batch_size=4,
                        epochs=300):
    # =============================================================================
    # Declare variables
    # =============================================================================
    img_size_x = image_size[0]
    img_size_y = image_size[1]
    img_dim = img_size_x * img_size_y

    img_dir = '/home/pi/Documents/2023 symbols/dataset3/data'
    gt_dir = '/home/pi/Documents/2023 symbols/dataset3/gt'
    checkpoint_filepath = '/home/pi/Documents/2023 symbols/dataset3/chpt/'

    # =============================================================================
    # Get number of data (image/label) 
    # =============================================================================
    anz_data = len(os.listdir(img_dir))
    anz_data = int(anz_data - 1)
    dataset = np.zeros((anz_data, img_size_x, img_size_y), dtype=float)
    ground_truth = np.zeros((anz_data), dtype=int)
    #print("dataset size:", anz_data)

    # =============================================================================
    # Callback for training
    # =============================================================================
    model_checkpoint_callback = callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath + str(num_training) + "-checkpoint.model.keras",
        save_weights_only=False,
        monitor='val_accuracy',
        mode='auto',
        save_best_only=True,
        verbose = 1)
    
    # =============================================================================
    # Read dataset
    # =============================================================================
    for i in range(0, anz_data, 1):
        img_name = img_dir + '/' + str(i) + '.png'      # create file names
        image = cv2.imread(img_name)                    # read image
        image = pic_prep(image, img_size_x, img_size_y) # prepare image
        dataset[i,:,:] = image                          # 2d-image to 3d-array
        
        txt_name = gt_dir + '/' + str(i) + '.txt'       # create gt file names
        txt_inhalt = np.genfromtxt(txt_name, delimiter=',') #ziffer in Truth schreiben
        ground_truth[i] = txt_inhalt
    #print(ground_truth)

    # =============================================================================
    # Prepare dataset: train set (80%) and test set (20%)
    # =============================================================================
    dataset = dataset.reshape(anz_data, img_dim) # convert into 2d array (all pixel in one row)
    ground_truth = ground_truth.reshape(anz_data, 1)

    dataset, ground_truth = unison_shuffle(dataset, ground_truth)

    trainset = np.random.choice(dataset.shape[0],
                                int(dataset.shape[0]*0.80), 
                                replace=False)
    train_data = dataset[trainset,:]
    train_gt = ground_truth[trainset]
    train_gt = utils.to_categorical(train_gt, 4)

    testset = np.delete(np.arange(0, len(ground_truth) ), 
                        trainset) 
    test_data = dataset[testset,:]
    test_gt = ground_truth[testset]
    test_gt = utils.to_categorical(test_gt, 4)
    #print(ground_truth)
    #print(dataset)
    #print(trainset)
    #print(train_data)
    #print(train_gt)

    # =============================================================================
    # Create neural network with e.g. 4 layers and (64, 32, 16, 4) neurons per layer.
    # =============================================================================
    model = models.Sequential()
    model.add(layers.Dense(num_neurons_per_layer[0], input_dim=img_dim,activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[1], activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[2], activation='relu'))
    model.add(layers.Dense(num_neurons_per_layer[3], activation='sigmoid'))
    model.compile(loss='mean_squared_error', 
                  optimizer='adam', 
                  metrics=['accuracy'])

    # =============================================================================
    # Train the neuronal network e.g. for e.g. 300 epochs.
    # =============================================================================
    history = model.fit(train_data, 
                        train_gt, 
                        batch_size=batch_size, 
                        epochs=epochs, 
                        verbose=0, 
                        shuffle=True, 
                        validation_data=(test_data, test_gt), 
                        callbacks=[model_checkpoint_callback])
    
    # =============================================================================
    # Plot train and val accuracy.
    # =============================================================================
    if plots_on:
        plt.plot(history.history['accuracy'], label='accuracy')
        plt.plot(history.history['val_accuracy'], label='val_accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend(loc='lower right')
        plt.show()

        # =========================================================================
        # Plot train and val loss.
        # =========================================================================
        plt.plot(history.history['loss'], label='loss')
        plt.plot(history.history['val_loss'], label='val_loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend(loc='lower left')
        plt.show()
    
    if test_on_specific_image:
        # =========================================================================
        # Load pretrained dataset weights to e.g. test on new (unseen) data.
        # =========================================================================
        model.load_weights(checkpoint_filepath + ".keras")   

        # =========================================================================
        # Test dataset on xxx.
        # =========================================================================
        score = model.evaluate(test_data, test_gt, verbose=1)
        print('Test score:', score[0])
        print('Test accuracy:', score[1])       

        # =========================================================================
        # Testing on a single image.
        # =========================================================================
        data_pred = np.zeros((1, img_size_x, img_size_y), dtype=float)
        img_pred = cv2.imread('/home/pi/Documents/2023 symbols/dataset3/data/217.png')
        img_pred = pic_prep(img_pred, img_size_x, img_size_y)
        data_pred[0,:,:] = img_pred
        data_pred = data_pred.reshape(1,img_dim)
        result = model.predict(data_pred)
        result = np.round(result, decimals=2)
        print("Probability for class (Kreuz, Kreis, Dreieck, Viereck) in percent", 
            result)
        
        # =============================================================================
        # Output class: 
        # translate class label (0,1,2,3) to class (Kreuz, Kreis, Dreieck, Viereck).
        # =============================================================================
        max_res = 0
        res_index = 4
        for i in range(0, 4, 1):
            if result[0,i] > max_res:
                max_res = result[0,i]
                res_index = i

        if res_index == 0:
            print('Das ist ein Kreuz!')
        elif res_index == 1:
            print('Das ist ein Kreis!')
        elif res_index == 2:
            print('Das ist ein Dreieck!')
        elif res_index == 3:
            print('Das ist ein Viereck!')
        elif res_index == 4:
            print('Du hast einen Fehler in deinem Programm!')

# %%
# =============================================================================
# Train multiple networks with differend image scales and neurons per layer
# =============================================================================
image_dims = [[32, 24],
              [32, 24],
              [32, 24]]
neurons_layers = [[64,32,16,4],
                  [32,32,16,4],
                  [16,32,16,4]]

# Train multiple times with different hyper parameters (dim img size, neurons per layer)
i = 1
for img_size, num_neurons in zip(image_dims, neurons_layers):
    print("Training", i, "with image size", img_size, "and", num_neurons, "neurons per layer")
    train_symbols_model(i, img_size, num_neurons, 4, 200)
    print("#################################################\n")
    i+=1
# Out:
# Training 1 with image size [32, 24] and [64, 32, 16, 4] neurons per layer
# /home/pi/ki-project/my_virtual_env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1: val_accuracy improved from -inf to 0.20455, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 2: val_accuracy improved from 0.20455 to 0.23864, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 3: val_accuracy did not improve from 0.23864
#
# Epoch 4: val_accuracy did not improve from 0.23864
#
# Epoch 5: val_accuracy did not improve from 0.23864
#
# Epoch 6: val_accuracy did not improve from 0.23864
#
# Epoch 7: val_accuracy did not improve from 0.23864
#
# Epoch 8: val_accuracy did not improve from 0.23864
#
# Epoch 9: val_accuracy did not improve from 0.23864
#
# Epoch 10: val_accuracy did not improve from 0.23864
#
# Epoch 11: val_accuracy did not improve from 0.23864
#
# Epoch 12: val_accuracy did not improve from 0.23864
#
# Epoch 13: val_accuracy did not improve from 0.23864
#
# Epoch 14: val_accuracy did not improve from 0.23864
#
# Epoch 15: val_accuracy did not improve from 0.23864
#
# Epoch 16: val_accuracy did not improve from 0.23864
#
# Epoch 17: val_accuracy did not improve from 0.23864
#
# Epoch 18: val_accuracy improved from 0.23864 to 0.25000, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 19: val_accuracy did not improve from 0.25000
#
# Epoch 20: val_accuracy improved from 0.25000 to 0.26136, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 21: val_accuracy did not improve from 0.26136
#
# Epoch 22: val_accuracy did not improve from 0.26136
#
# Epoch 23: val_accuracy did not improve from 0.26136
#
# Epoch 24: val_accuracy did not improve from 0.26136
#
# Epoch 25: val_accuracy did not improve from 0.26136
#
# Epoch 26: val_accuracy did not improve from 0.26136
#
# Epoch 27: val_accuracy improved from 0.26136 to 0.29545, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 28: val_accuracy improved from 0.29545 to 0.30682, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 29: val_accuracy did not improve from 0.30682
#
# Epoch 30: val_accuracy did not improve from 0.30682
#
# Epoch 31: val_accuracy did not improve from 0.30682
#
# Epoch 32: val_accuracy did not improve from 0.30682
#
# Epoch 33: val_accuracy did not improve from 0.30682
#
# Epoch 34: val_accuracy did not improve from 0.30682
#
# Epoch 35: val_accuracy did not improve from 0.30682
#
# Epoch 36: val_accuracy did not improve from 0.30682
#
# Epoch 37: val_accuracy did not improve from 0.30682
#
# Epoch 38: val_accuracy did not improve from 0.30682
#
# Epoch 39: val_accuracy did not improve from 0.30682
#
# Epoch 40: val_accuracy did not improve from 0.30682
#
# Epoch 41: val_accuracy did not improve from 0.30682
#
# Epoch 42: val_accuracy did not improve from 0.30682
#
# Epoch 43: val_accuracy did not improve from 0.30682
#
# Epoch 44: val_accuracy did not improve from 0.30682
#
# Epoch 45: val_accuracy did not improve from 0.30682
#
# Epoch 46: val_accuracy improved from 0.30682 to 0.35227, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 47: val_accuracy did not improve from 0.35227
#
# Epoch 48: val_accuracy did not improve from 0.35227
#
# Epoch 49: val_accuracy did not improve from 0.35227
#
# Epoch 50: val_accuracy did not improve from 0.35227
#
# Epoch 51: val_accuracy did not improve from 0.35227
#
# Epoch 52: val_accuracy improved from 0.35227 to 0.36364, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 53: val_accuracy did not improve from 0.36364
#
# Epoch 54: val_accuracy did not improve from 0.36364
#
# Epoch 55: val_accuracy improved from 0.36364 to 0.37500, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 56: val_accuracy did not improve from 0.37500
#
# Epoch 57: val_accuracy did not improve from 0.37500
#
# Epoch 58: val_accuracy improved from 0.37500 to 0.43182, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 59: val_accuracy did not improve from 0.43182
#
# Epoch 60: val_accuracy did not improve from 0.43182
#
# Epoch 61: val_accuracy did not improve from 0.43182
#
# Epoch 62: val_accuracy did not improve from 0.43182
#
# Epoch 63: val_accuracy did not improve from 0.43182
#
# Epoch 64: val_accuracy did not improve from 0.43182
#
# Epoch 65: val_accuracy did not improve from 0.43182
#
# Epoch 66: val_accuracy did not improve from 0.43182
#
# Epoch 67: val_accuracy did not improve from 0.43182
#
# Epoch 68: val_accuracy did not improve from 0.43182
#
# Epoch 69: val_accuracy did not improve from 0.43182
#
# Epoch 70: val_accuracy did not improve from 0.43182
#
# Epoch 71: val_accuracy did not improve from 0.43182
#
# Epoch 72: val_accuracy did not improve from 0.43182
#
# Epoch 73: val_accuracy did not improve from 0.43182
#
# Epoch 74: val_accuracy did not improve from 0.43182
#
# Epoch 75: val_accuracy improved from 0.43182 to 0.45455, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 76: val_accuracy did not improve from 0.45455
#
# Epoch 77: val_accuracy did not improve from 0.45455
#
# Epoch 78: val_accuracy did not improve from 0.45455
#
# Epoch 79: val_accuracy did not improve from 0.45455
#
# Epoch 80: val_accuracy did not improve from 0.45455
#
# Epoch 81: val_accuracy did not improve from 0.45455
#
# Epoch 82: val_accuracy did not improve from 0.45455
#
# Epoch 83: val_accuracy improved from 0.45455 to 0.46591, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 84: val_accuracy did not improve from 0.46591
#
# Epoch 85: val_accuracy did not improve from 0.46591
#
# Epoch 86: val_accuracy did not improve from 0.46591
#
# Epoch 87: val_accuracy did not improve from 0.46591
#
# Epoch 88: val_accuracy did not improve from 0.46591
#
# Epoch 89: val_accuracy did not improve from 0.46591
#
# Epoch 90: val_accuracy did not improve from 0.46591
#
# Epoch 91: val_accuracy did not improve from 0.46591
#
# Epoch 92: val_accuracy did not improve from 0.46591
#
# Epoch 93: val_accuracy did not improve from 0.46591
#
# Epoch 94: val_accuracy did not improve from 0.46591
#
# Epoch 95: val_accuracy did not improve from 0.46591
#
# Epoch 96: val_accuracy did not improve from 0.46591
#
# Epoch 97: val_accuracy did not improve from 0.46591
#
# Epoch 98: val_accuracy did not improve from 0.46591
#
# Epoch 99: val_accuracy did not improve from 0.46591
#
# Epoch 100: val_accuracy did not improve from 0.46591
#
# Epoch 101: val_accuracy did not improve from 0.46591
#
# Epoch 102: val_accuracy did not improve from 0.46591
#
# Epoch 103: val_accuracy did not improve from 0.46591
#
# Epoch 104: val_accuracy did not improve from 0.46591
#
# Epoch 105: val_accuracy did not improve from 0.46591
#
# Epoch 106: val_accuracy did not improve from 0.46591
#
# Epoch 107: val_accuracy improved from 0.46591 to 0.47727, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 108: val_accuracy did not improve from 0.47727
#
# Epoch 109: val_accuracy did not improve from 0.47727
#
# Epoch 110: val_accuracy did not improve from 0.47727
#
# Epoch 111: val_accuracy did not improve from 0.47727
#
# Epoch 112: val_accuracy did not improve from 0.47727
#
# Epoch 113: val_accuracy did not improve from 0.47727
#
# Epoch 114: val_accuracy did not improve from 0.47727
#
# Epoch 115: val_accuracy did not improve from 0.47727
#
# Epoch 116: val_accuracy did not improve from 0.47727
#
# Epoch 117: val_accuracy did not improve from 0.47727
#
# Epoch 118: val_accuracy did not improve from 0.47727
#
# Epoch 119: val_accuracy did not improve from 0.47727
#
# Epoch 120: val_accuracy did not improve from 0.47727
#
# Epoch 121: val_accuracy did not improve from 0.47727
#
# Epoch 122: val_accuracy did not improve from 0.47727
#
# Epoch 123: val_accuracy did not improve from 0.47727
#
# Epoch 124: val_accuracy improved from 0.47727 to 0.48864, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 125: val_accuracy did not improve from 0.48864
#
# Epoch 126: val_accuracy did not improve from 0.48864
#
# Epoch 127: val_accuracy did not improve from 0.48864
#
# Epoch 128: val_accuracy did not improve from 0.48864
#
# Epoch 129: val_accuracy did not improve from 0.48864
#
# Epoch 130: val_accuracy did not improve from 0.48864
#
# Epoch 131: val_accuracy did not improve from 0.48864
#
# Epoch 132: val_accuracy did not improve from 0.48864
#
# Epoch 133: val_accuracy did not improve from 0.48864
#
# Epoch 134: val_accuracy did not improve from 0.48864
#
# Epoch 135: val_accuracy did not improve from 0.48864
#
# Epoch 136: val_accuracy did not improve from 0.48864
#
# Epoch 137: val_accuracy did not improve from 0.48864
#
# Epoch 138: val_accuracy did not improve from 0.48864
#
# Epoch 139: val_accuracy did not improve from 0.48864
#
# Epoch 140: val_accuracy did not improve from 0.48864
#
# Epoch 141: val_accuracy did not improve from 0.48864
#
# Epoch 142: val_accuracy did not improve from 0.48864
#
# Epoch 143: val_accuracy did not improve from 0.48864
#
# Epoch 144: val_accuracy did not improve from 0.48864
#
# Epoch 145: val_accuracy did not improve from 0.48864
#
# Epoch 146: val_accuracy did not improve from 0.48864
#
# Epoch 147: val_accuracy did not improve from 0.48864
#
# Epoch 148: val_accuracy did not improve from 0.48864
#
# Epoch 149: val_accuracy did not improve from 0.48864
#
# Epoch 150: val_accuracy did not improve from 0.48864
#
# Epoch 151: val_accuracy did not improve from 0.48864
#
# Epoch 152: val_accuracy did not improve from 0.48864
#
# Epoch 153: val_accuracy did not improve from 0.48864
#
# Epoch 154: val_accuracy did not improve from 0.48864
#
# Epoch 155: val_accuracy did not improve from 0.48864
#
# Epoch 156: val_accuracy did not improve from 0.48864
#
# Epoch 157: val_accuracy did not improve from 0.48864
#
# Epoch 158: val_accuracy did not improve from 0.48864
#
# Epoch 159: val_accuracy did not improve from 0.48864
#
# Epoch 160: val_accuracy did not improve from 0.48864
#
# Epoch 161: val_accuracy did not improve from 0.48864
#
# Epoch 162: val_accuracy did not improve from 0.48864
#
# Epoch 163: val_accuracy did not improve from 0.48864
#
# Epoch 164: val_accuracy did not improve from 0.48864
#
# Epoch 165: val_accuracy did not improve from 0.48864
#
# Epoch 166: val_accuracy did not improve from 0.48864
#
# Epoch 167: val_accuracy did not improve from 0.48864
#
# Epoch 168: val_accuracy improved from 0.48864 to 0.50000, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 169: val_accuracy did not improve from 0.50000
#
# Epoch 170: val_accuracy did not improve from 0.50000
#
# Epoch 171: val_accuracy did not improve from 0.50000
#
# Epoch 172: val_accuracy did not improve from 0.50000
#
# Epoch 173: val_accuracy did not improve from 0.50000
#
# Epoch 174: val_accuracy did not improve from 0.50000
#
# Epoch 175: val_accuracy did not improve from 0.50000
#
# Epoch 176: val_accuracy did not improve from 0.50000
#
# Epoch 177: val_accuracy did not improve from 0.50000
#
# Epoch 178: val_accuracy did not improve from 0.50000
#
# Epoch 179: val_accuracy did not improve from 0.50000
#
# Epoch 180: val_accuracy did not improve from 0.50000
#
# Epoch 181: val_accuracy did not improve from 0.50000
#
# Epoch 182: val_accuracy did not improve from 0.50000
#
# Epoch 183: val_accuracy did not improve from 0.50000
#
# Epoch 184: val_accuracy improved from 0.50000 to 0.51136, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
#
# Epoch 185: val_accuracy did not improve from 0.51136
#
# Epoch 186: val_accuracy did not improve from 0.51136
#
# Epoch 187: val_accuracy did not improve from 0.51136
#
# Epoch 188: val_accuracy did not improve from 0.51136
#
# Epoch 189: val_accuracy did not improve from 0.51136
#
# Epoch 190: val_accuracy did not improve from 0.51136
#
# Epoch 191: val_accuracy did not improve from 0.51136
#
# Epoch 192: val_accuracy did not improve from 0.51136
#
# Epoch 193: val_accuracy did not improve from 0.51136
#
# Epoch 194: val_accuracy did not improve from 0.51136
#
# Epoch 195: val_accuracy did not improve from 0.51136
#
# Epoch 196: val_accuracy did not improve from 0.51136
#
# Epoch 197: val_accuracy did not improve from 0.51136
#
# Epoch 198: val_accuracy did not improve from 0.51136
#
# Epoch 199: val_accuracy did not improve from 0.51136
#
# Epoch 200: val_accuracy improved from 0.51136 to 0.52273, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/1-checkpoint.model.keras
# #################################################
#
# Training 2 with image size [32, 24] and [32, 32, 16, 4] neurons per layer
#
# Epoch 1: val_accuracy improved from -inf to 0.30682, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 2: val_accuracy did not improve from 0.30682
#
# Epoch 3: val_accuracy did not improve from 0.30682
#
# Epoch 4: val_accuracy did not improve from 0.30682
#
# Epoch 5: val_accuracy did not improve from 0.30682
#
# Epoch 6: val_accuracy did not improve from 0.30682
#
# Epoch 7: val_accuracy did not improve from 0.30682
#
# Epoch 8: val_accuracy did not improve from 0.30682
#
# Epoch 9: val_accuracy did not improve from 0.30682
#
# Epoch 10: val_accuracy did not improve from 0.30682
#
# Epoch 11: val_accuracy did not improve from 0.30682
#
# Epoch 12: val_accuracy did not improve from 0.30682
#
# Epoch 13: val_accuracy did not improve from 0.30682
#
# Epoch 14: val_accuracy did not improve from 0.30682
#
# Epoch 15: val_accuracy did not improve from 0.30682
#
# Epoch 16: val_accuracy did not improve from 0.30682
#
# Epoch 17: val_accuracy did not improve from 0.30682
#
# Epoch 18: val_accuracy did not improve from 0.30682
#
# Epoch 19: val_accuracy improved from 0.30682 to 0.32955, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 20: val_accuracy did not improve from 0.32955
#
# Epoch 21: val_accuracy did not improve from 0.32955
#
# Epoch 22: val_accuracy did not improve from 0.32955
#
# Epoch 23: val_accuracy did not improve from 0.32955
#
# Epoch 24: val_accuracy did not improve from 0.32955
#
# Epoch 25: val_accuracy did not improve from 0.32955
#
# Epoch 26: val_accuracy did not improve from 0.32955
#
# Epoch 27: val_accuracy did not improve from 0.32955
#
# Epoch 28: val_accuracy did not improve from 0.32955
#
# Epoch 29: val_accuracy did not improve from 0.32955
#
# Epoch 30: val_accuracy did not improve from 0.32955
#
# Epoch 31: val_accuracy did not improve from 0.32955
#
# Epoch 32: val_accuracy did not improve from 0.32955
#
# Epoch 33: val_accuracy did not improve from 0.32955
#
# Epoch 34: val_accuracy did not improve from 0.32955
#
# Epoch 35: val_accuracy did not improve from 0.32955
#
# Epoch 36: val_accuracy did not improve from 0.32955
#
# Epoch 37: val_accuracy improved from 0.32955 to 0.34091, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 38: val_accuracy did not improve from 0.34091
#
# Epoch 39: val_accuracy did not improve from 0.34091
#
# Epoch 40: val_accuracy did not improve from 0.34091
#
# Epoch 41: val_accuracy did not improve from 0.34091
#
# Epoch 42: val_accuracy improved from 0.34091 to 0.36364, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 43: val_accuracy did not improve from 0.36364
#
# Epoch 44: val_accuracy improved from 0.36364 to 0.45455, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 45: val_accuracy did not improve from 0.45455
#
# Epoch 46: val_accuracy did not improve from 0.45455
#
# Epoch 47: val_accuracy did not improve from 0.45455
#
# Epoch 48: val_accuracy did not improve from 0.45455
#
# Epoch 49: val_accuracy did not improve from 0.45455
#
# Epoch 50: val_accuracy did not improve from 0.45455
#
# Epoch 51: val_accuracy did not improve from 0.45455
#
# Epoch 52: val_accuracy did not improve from 0.45455
#
# Epoch 53: val_accuracy did not improve from 0.45455
#
# Epoch 54: val_accuracy did not improve from 0.45455
#
# Epoch 55: val_accuracy did not improve from 0.45455
#
# Epoch 56: val_accuracy did not improve from 0.45455
#
# Epoch 57: val_accuracy did not improve from 0.45455
#
# Epoch 58: val_accuracy did not improve from 0.45455
#
# Epoch 59: val_accuracy did not improve from 0.45455
#
# Epoch 60: val_accuracy did not improve from 0.45455
#
# Epoch 61: val_accuracy did not improve from 0.45455
#
# Epoch 62: val_accuracy did not improve from 0.45455
#
# Epoch 63: val_accuracy did not improve from 0.45455
#
# Epoch 64: val_accuracy did not improve from 0.45455
#
# Epoch 65: val_accuracy did not improve from 0.45455
#
# Epoch 66: val_accuracy did not improve from 0.45455
#
# Epoch 67: val_accuracy did not improve from 0.45455
#
# Epoch 68: val_accuracy did not improve from 0.45455
#
# Epoch 69: val_accuracy did not improve from 0.45455
#
# Epoch 70: val_accuracy did not improve from 0.45455
#
# Epoch 71: val_accuracy did not improve from 0.45455
#
# Epoch 72: val_accuracy did not improve from 0.45455
#
# Epoch 73: val_accuracy did not improve from 0.45455
#
# Epoch 74: val_accuracy did not improve from 0.45455
#
# Epoch 75: val_accuracy did not improve from 0.45455
#
# Epoch 76: val_accuracy did not improve from 0.45455
#
# Epoch 77: val_accuracy did not improve from 0.45455
#
# Epoch 78: val_accuracy did not improve from 0.45455
#
# Epoch 79: val_accuracy did not improve from 0.45455
#
# Epoch 80: val_accuracy did not improve from 0.45455
#
# Epoch 81: val_accuracy did not improve from 0.45455
#
# Epoch 82: val_accuracy did not improve from 0.45455
#
# Epoch 83: val_accuracy did not improve from 0.45455
#
# Epoch 84: val_accuracy did not improve from 0.45455
#
# Epoch 85: val_accuracy did not improve from 0.45455
#
# Epoch 86: val_accuracy did not improve from 0.45455
#
# Epoch 87: val_accuracy did not improve from 0.45455
#
# Epoch 88: val_accuracy did not improve from 0.45455
#
# Epoch 89: val_accuracy did not improve from 0.45455
#
# Epoch 90: val_accuracy did not improve from 0.45455
#
# Epoch 91: val_accuracy did not improve from 0.45455
#
# Epoch 92: val_accuracy did not improve from 0.45455
#
# Epoch 93: val_accuracy did not improve from 0.45455
#
# Epoch 94: val_accuracy did not improve from 0.45455
#
# Epoch 95: val_accuracy did not improve from 0.45455
#
# Epoch 96: val_accuracy did not improve from 0.45455
#
# Epoch 97: val_accuracy did not improve from 0.45455
#
# Epoch 98: val_accuracy did not improve from 0.45455
#
# Epoch 99: val_accuracy did not improve from 0.45455
#
# Epoch 100: val_accuracy did not improve from 0.45455
#
# Epoch 101: val_accuracy did not improve from 0.45455
#
# Epoch 102: val_accuracy did not improve from 0.45455
#
# Epoch 103: val_accuracy did not improve from 0.45455
#
# Epoch 104: val_accuracy did not improve from 0.45455
#
# Epoch 105: val_accuracy did not improve from 0.45455
#
# Epoch 106: val_accuracy did not improve from 0.45455
#
# Epoch 107: val_accuracy did not improve from 0.45455
#
# Epoch 108: val_accuracy did not improve from 0.45455
#
# Epoch 109: val_accuracy did not improve from 0.45455
#
# Epoch 110: val_accuracy did not improve from 0.45455
#
# Epoch 111: val_accuracy did not improve from 0.45455
#
# Epoch 112: val_accuracy did not improve from 0.45455
#
# Epoch 113: val_accuracy did not improve from 0.45455
#
# Epoch 114: val_accuracy improved from 0.45455 to 0.46591, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 115: val_accuracy did not improve from 0.46591
#
# Epoch 116: val_accuracy did not improve from 0.46591
#
# Epoch 117: val_accuracy did not improve from 0.46591
#
# Epoch 118: val_accuracy did not improve from 0.46591
#
# Epoch 119: val_accuracy did not improve from 0.46591
#
# Epoch 120: val_accuracy did not improve from 0.46591
#
# Epoch 121: val_accuracy did not improve from 0.46591
#
# Epoch 122: val_accuracy did not improve from 0.46591
#
# Epoch 123: val_accuracy did not improve from 0.46591
#
# Epoch 124: val_accuracy did not improve from 0.46591
#
# Epoch 125: val_accuracy did not improve from 0.46591
#
# Epoch 126: val_accuracy did not improve from 0.46591
#
# Epoch 127: val_accuracy did not improve from 0.46591
#
# Epoch 128: val_accuracy did not improve from 0.46591
#
# Epoch 129: val_accuracy did not improve from 0.46591
#
# Epoch 130: val_accuracy did not improve from 0.46591
#
# Epoch 131: val_accuracy did not improve from 0.46591
#
# Epoch 132: val_accuracy did not improve from 0.46591
#
# Epoch 133: val_accuracy did not improve from 0.46591
#
# Epoch 134: val_accuracy did not improve from 0.46591
#
# Epoch 135: val_accuracy did not improve from 0.46591
#
# Epoch 136: val_accuracy did not improve from 0.46591
#
# Epoch 137: val_accuracy did not improve from 0.46591
#
# Epoch 138: val_accuracy did not improve from 0.46591
#
# Epoch 139: val_accuracy did not improve from 0.46591
#
# Epoch 140: val_accuracy did not improve from 0.46591
#
# Epoch 141: val_accuracy did not improve from 0.46591
#
# Epoch 142: val_accuracy did not improve from 0.46591
#
# Epoch 143: val_accuracy did not improve from 0.46591
#
# Epoch 144: val_accuracy did not improve from 0.46591
#
# Epoch 145: val_accuracy did not improve from 0.46591
#
# Epoch 146: val_accuracy did not improve from 0.46591
#
# Epoch 147: val_accuracy improved from 0.46591 to 0.47727, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/2-checkpoint.model.keras
#
# Epoch 148: val_accuracy did not improve from 0.47727
#
# Epoch 149: val_accuracy did not improve from 0.47727
#
# Epoch 150: val_accuracy did not improve from 0.47727
#
# Epoch 151: val_accuracy did not improve from 0.47727
#
# Epoch 152: val_accuracy did not improve from 0.47727
#
# Epoch 153: val_accuracy did not improve from 0.47727
#
# Epoch 154: val_accuracy did not improve from 0.47727
#
# Epoch 155: val_accuracy did not improve from 0.47727
#
# Epoch 156: val_accuracy did not improve from 0.47727
#
# Epoch 157: val_accuracy did not improve from 0.47727
#
# Epoch 158: val_accuracy did not improve from 0.47727
#
# Epoch 159: val_accuracy did not improve from 0.47727
#
# Epoch 160: val_accuracy did not improve from 0.47727
#
# Epoch 161: val_accuracy did not improve from 0.47727
#
# Epoch 162: val_accuracy did not improve from 0.47727
#
# Epoch 163: val_accuracy did not improve from 0.47727
#
# Epoch 164: val_accuracy did not improve from 0.47727
#
# Epoch 165: val_accuracy did not improve from 0.47727
#
# Epoch 166: val_accuracy did not improve from 0.47727
#
# Epoch 167: val_accuracy did not improve from 0.47727
#
# Epoch 168: val_accuracy did not improve from 0.47727
#
# Epoch 169: val_accuracy did not improve from 0.47727
#
# Epoch 170: val_accuracy did not improve from 0.47727
#
# Epoch 171: val_accuracy did not improve from 0.47727
#
# Epoch 172: val_accuracy did not improve from 0.47727
#
# Epoch 173: val_accuracy did not improve from 0.47727
#
# Epoch 174: val_accuracy did not improve from 0.47727
#
# Epoch 175: val_accuracy did not improve from 0.47727
#
# Epoch 176: val_accuracy did not improve from 0.47727
#
# Epoch 177: val_accuracy did not improve from 0.47727
#
# Epoch 178: val_accuracy did not improve from 0.47727
#
# Epoch 179: val_accuracy did not improve from 0.47727
#
# Epoch 180: val_accuracy did not improve from 0.47727
#
# Epoch 181: val_accuracy did not improve from 0.47727
#
# Epoch 182: val_accuracy did not improve from 0.47727
#
# Epoch 183: val_accuracy did not improve from 0.47727
#
# Epoch 184: val_accuracy did not improve from 0.47727
#
# Epoch 185: val_accuracy did not improve from 0.47727
#
# Epoch 186: val_accuracy did not improve from 0.47727
#
# Epoch 187: val_accuracy did not improve from 0.47727
#
# Epoch 188: val_accuracy did not improve from 0.47727
#
# Epoch 189: val_accuracy did not improve from 0.47727
#
# Epoch 190: val_accuracy did not improve from 0.47727
#
# Epoch 191: val_accuracy did not improve from 0.47727
#
# Epoch 192: val_accuracy did not improve from 0.47727
#
# Epoch 193: val_accuracy did not improve from 0.47727
#
# Epoch 194: val_accuracy did not improve from 0.47727
#
# Epoch 195: val_accuracy did not improve from 0.47727
#
# Epoch 196: val_accuracy did not improve from 0.47727
#
# Epoch 197: val_accuracy did not improve from 0.47727
#
# Epoch 198: val_accuracy did not improve from 0.47727
#
# Epoch 199: val_accuracy did not improve from 0.47727
#
# Epoch 200: val_accuracy did not improve from 0.47727
# #################################################
#
# Training 3 with image size [32, 24] and [16, 32, 16, 4] neurons per layer
#
# Epoch 1: val_accuracy improved from -inf to 0.23864, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/3-checkpoint.model.keras
#
# Epoch 2: val_accuracy did not improve from 0.23864
#
# Epoch 3: val_accuracy did not improve from 0.23864
#
# Epoch 4: val_accuracy did not improve from 0.23864
#
# Epoch 5: val_accuracy improved from 0.23864 to 0.25000, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/3-checkpoint.model.keras
#
# Epoch 6: val_accuracy did not improve from 0.25000
#
# Epoch 7: val_accuracy did not improve from 0.25000
#
# Epoch 8: val_accuracy did not improve from 0.25000
#
# Epoch 9: val_accuracy did not improve from 0.25000
#
# Epoch 10: val_accuracy did not improve from 0.25000
#
# Epoch 11: val_accuracy did not improve from 0.25000
#
# Epoch 12: val_accuracy did not improve from 0.25000
#
# Epoch 13: val_accuracy did not improve from 0.25000
#
# Epoch 14: val_accuracy did not improve from 0.25000
#
# Epoch 15: val_accuracy did not improve from 0.25000
#
# Epoch 16: val_accuracy did not improve from 0.25000
#
# Epoch 17: val_accuracy did not improve from 0.25000
#
# Epoch 18: val_accuracy improved from 0.25000 to 0.28409, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/3-checkpoint.model.keras
#
# Epoch 19: val_accuracy did not improve from 0.28409
#
# Epoch 20: val_accuracy did not improve from 0.28409
#
# Epoch 21: val_accuracy did not improve from 0.28409
#
# Epoch 22: val_accuracy did not improve from 0.28409
#
# Epoch 23: val_accuracy did not improve from 0.28409
#
# Epoch 24: val_accuracy did not improve from 0.28409
#
# Epoch 25: val_accuracy did not improve from 0.28409
#
# Epoch 26: val_accuracy did not improve from 0.28409
#
# Epoch 27: val_accuracy did not improve from 0.28409
#
# Epoch 28: val_accuracy improved from 0.28409 to 0.42045, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/3-checkpoint.model.keras
#
# Epoch 29: val_accuracy did not improve from 0.42045
#
# Epoch 30: val_accuracy did not improve from 0.42045
#
# Epoch 31: val_accuracy did not improve from 0.42045
#
# Epoch 32: val_accuracy did not improve from 0.42045
#
# Epoch 33: val_accuracy did not improve from 0.42045
#
# Epoch 34: val_accuracy did not improve from 0.42045
#
# Epoch 35: val_accuracy did not improve from 0.42045
#
# Epoch 36: val_accuracy did not improve from 0.42045
#
# Epoch 37: val_accuracy did not improve from 0.42045
#
# Epoch 38: val_accuracy did not improve from 0.42045
#
# Epoch 39: val_accuracy did not improve from 0.42045
#
# Epoch 40: val_accuracy did not improve from 0.42045
#
# Epoch 41: val_accuracy did not improve from 0.42045
#
# Epoch 42: val_accuracy did not improve from 0.42045
#
# Epoch 43: val_accuracy did not improve from 0.42045
#
# Epoch 44: val_accuracy did not improve from 0.42045
#
# Epoch 45: val_accuracy did not improve from 0.42045
#
# Epoch 46: val_accuracy did not improve from 0.42045
#
# Epoch 47: val_accuracy did not improve from 0.42045
#
# Epoch 48: val_accuracy did not improve from 0.42045
#
# Epoch 49: val_accuracy did not improve from 0.42045
#
# Epoch 50: val_accuracy did not improve from 0.42045
#
# Epoch 51: val_accuracy did not improve from 0.42045
#
# Epoch 52: val_accuracy did not improve from 0.42045
#
# Epoch 53: val_accuracy did not improve from 0.42045
#
# Epoch 54: val_accuracy did not improve from 0.42045
#
# Epoch 55: val_accuracy did not improve from 0.42045
#
# Epoch 56: val_accuracy did not improve from 0.42045
#
# Epoch 57: val_accuracy did not improve from 0.42045
#
# Epoch 58: val_accuracy did not improve from 0.42045
#
# Epoch 59: val_accuracy did not improve from 0.42045
#
# Epoch 60: val_accuracy did not improve from 0.42045
#
# Epoch 61: val_accuracy did not improve from 0.42045
#
# Epoch 62: val_accuracy improved from 0.42045 to 0.47727, saving model to /home/pi/Documents/2023 symbols/dataset3/chpt/3-checkpoint.model.keras
#
# Epoch 63: val_accuracy did not improve from 0.47727
#
# Epoch 64: val_accuracy did not improve from 0.47727
#
# Epoch 65: val_accuracy did not improve from 0.47727
#
# Epoch 66: val_accuracy did not improve from 0.47727
#
# Epoch 67: val_accuracy did not improve from 0.47727
#
# Epoch 68: val_accuracy did not improve from 0.47727
#
# Epoch 69: val_accuracy did not improve from 0.47727
#
# Epoch 70: val_accuracy did not improve from 0.47727
#
# Epoch 71: val_accuracy did not improve from 0.47727
#
# Epoch 72: val_accuracy did not improve from 0.47727
#
# Epoch 73: val_accuracy did not improve from 0.47727
#
# Epoch 74: val_accuracy did not improve from 0.47727
#
# Epoch 75: val_accuracy did not improve from 0.47727
#
# Epoch 76: val_accuracy did not improve from 0.47727
#
# Epoch 77: val_accuracy did not improve from 0.47727
#
# Epoch 78: val_accuracy did not improve from 0.47727
#
# Epoch 79: val_accuracy did not improve from 0.47727
#
# Epoch 80: val_accuracy did not improve from 0.47727
#
# Epoch 81: val_accuracy did not improve from 0.47727
#
# Epoch 82: val_accuracy did not improve from 0.47727
#
# Epoch 83: val_accuracy did not improve from 0.47727
#
# Epoch 84: val_accuracy did not improve from 0.47727
#
# Epoch 85: val_accuracy did not improve from 0.47727
#
# Epoch 86: val_accuracy did not improve from 0.47727
#
# Epoch 87: val_accuracy did not improve from 0.47727
#
# Epoch 88: val_accuracy did not improve from 0.47727
#
# Epoch 89: val_accuracy did not improve from 0.47727
#
# Epoch 90: val_accuracy did not improve from 0.47727
#
# Epoch 91: val_accuracy did not improve from 0.47727
#
# Epoch 92: val_accuracy did not improve from 0.47727
#
# Epoch 93: val_accuracy did not improve from 0.47727
#
# Epoch 94: val_accuracy did not improve from 0.47727
#
# Epoch 95: val_accuracy did not improve from 0.47727
#
# Epoch 96: val_accuracy did not improve from 0.47727
#
# Epoch 97: val_accuracy did not improve from 0.47727
#
# Epoch 98: val_accuracy did not improve from 0.47727
#
# Epoch 99: val_accuracy did not improve from 0.47727
#
# Epoch 100: val_accuracy did not improve from 0.47727
#
# Epoch 101: val_accuracy did not improve from 0.47727
#
# Epoch 102: val_accuracy did not improve from 0.47727
#
# Epoch 103: val_accuracy did not improve from 0.47727
#
# Epoch 104: val_accuracy did not improve from 0.47727
#
# Epoch 105: val_accuracy did not improve from 0.47727
#
# Epoch 106: val_accuracy did not improve from 0.47727
#
# Epoch 107: val_accuracy did not improve from 0.47727
#
# Epoch 108: val_accuracy did not improve from 0.47727
#
# Epoch 109: val_accuracy did not improve from 0.47727
#
# Epoch 110: val_accuracy did not improve from 0.47727
#
# Epoch 111: val_accuracy did not improve from 0.47727
#
# Epoch 112: val_accuracy did not improve from 0.47727
#
# Epoch 113: val_accuracy did not improve from 0.47727
#
# Epoch 114: val_accuracy did not improve from 0.47727
#
# Epoch 115: val_accuracy did not improve from 0.47727
#
# Epoch 116: val_accuracy did not improve from 0.47727
#
# Epoch 117: val_accuracy did not improve from 0.47727
#
# Epoch 118: val_accuracy did not improve from 0.47727
#
# Epoch 119: val_accuracy did not improve from 0.47727
#
# Epoch 120: val_accuracy did not improve from 0.47727
#
# Epoch 121: val_accuracy did not improve from 0.47727
#
# Epoch 122: val_accuracy did not improve from 0.47727
#
# Epoch 123: val_accuracy did not improve from 0.47727
#
# Epoch 124: val_accuracy did not improve from 0.47727
#
# Epoch 125: val_accuracy did not improve from 0.47727
#
# Epoch 126: val_accuracy did not improve from 0.47727
#
# Epoch 127: val_accuracy did not improve from 0.47727
#
# Epoch 128: val_accuracy did not improve from 0.47727
#
# Epoch 129: val_accuracy did not improve from 0.47727
#
# Epoch 130: val_accuracy did not improve from 0.47727
#
# Epoch 131: val_accuracy did not improve from 0.47727
#
# Epoch 132: val_accuracy did not improve from 0.47727
#
# Epoch 133: val_accuracy did not improve from 0.47727
#
# Epoch 134: val_accuracy did not improve from 0.47727
#
# Epoch 135: val_accuracy did not improve from 0.47727
#
# Epoch 136: val_accuracy did not improve from 0.47727
#
# Epoch 137: val_accuracy did not improve from 0.47727
#
# Epoch 138: val_accuracy did not improve from 0.47727
#
# Epoch 139: val_accuracy did not improve from 0.47727
#
# Epoch 140: val_accuracy did not improve from 0.47727
#
# Epoch 141: val_accuracy did not improve from 0.47727
#
# Epoch 142: val_accuracy did not improve from 0.47727
#
# Epoch 143: val_accuracy did not improve from 0.47727
#
# Epoch 144: val_accuracy did not improve from 0.47727
#
# Epoch 145: val_accuracy did not improve from 0.47727
#
# Epoch 146: val_accuracy did not improve from 0.47727
#
# Epoch 147: val_accuracy did not improve from 0.47727
#
# Epoch 148: val_accuracy did not improve from 0.47727
#
# Epoch 149: val_accuracy did not improve from 0.47727
#
# Epoch 150: val_accuracy did not improve from 0.47727
#
# Epoch 151: val_accuracy did not improve from 0.47727
#
# Epoch 152: val_accuracy did not improve from 0.47727
#
# Epoch 153: val_accuracy did not improve from 0.47727
#
# Epoch 154: val_accuracy did not improve from 0.47727
#
# Epoch 155: val_accuracy did not improve from 0.47727
#
# Epoch 156: val_accuracy did not improve from 0.47727
#
# Epoch 157: val_accuracy did not improve from 0.47727
#
# Epoch 158: val_accuracy did not improve from 0.47727
#
# Epoch 159: val_accuracy did not improve from 0.47727
#
# Epoch 160: val_accuracy did not improve from 0.47727
#
# Epoch 161: val_accuracy did not improve from 0.47727
#
# Epoch 162: val_accuracy did not improve from 0.47727
#
# Epoch 163: val_accuracy did not improve from 0.47727
#
# Epoch 164: val_accuracy did not improve from 0.47727
#
# Epoch 165: val_accuracy did not improve from 0.47727
#
# Epoch 166: val_accuracy did not improve from 0.47727
#
# Epoch 167: val_accuracy did not improve from 0.47727
#
# Epoch 168: val_accuracy did not improve from 0.47727
#
# Epoch 169: val_accuracy did not improve from 0.47727
#
# Epoch 170: val_accuracy did not improve from 0.47727
#
# Epoch 171: val_accuracy did not improve from 0.47727
#
# Epoch 172: val_accuracy did not improve from 0.47727
#
# Epoch 173: val_accuracy did not improve from 0.47727
#
# Epoch 174: val_accuracy did not improve from 0.47727
#
# Epoch 175: val_accuracy did not improve from 0.47727
#
# Epoch 176: val_accuracy did not improve from 0.47727
#
# Epoch 177: val_accuracy did not improve from 0.47727
#
# Epoch 178: val_accuracy did not improve from 0.47727
#
# Epoch 179: val_accuracy did not improve from 0.47727
#
# Epoch 180: val_accuracy did not improve from 0.47727
#
# Epoch 181: val_accuracy did not improve from 0.47727
#
# Epoch 182: val_accuracy did not improve from 0.47727
#
# Epoch 183: val_accuracy did not improve from 0.47727
#
# Epoch 184: val_accuracy did not improve from 0.47727
#
# Epoch 185: val_accuracy did not improve from 0.47727
#
# Epoch 186: val_accuracy did not improve from 0.47727
#
# Epoch 187: val_accuracy did not improve from 0.47727
#
# Epoch 188: val_accuracy did not improve from 0.47727
#
# Epoch 189: val_accuracy did not improve from 0.47727
#
# Epoch 190: val_accuracy did not improve from 0.47727
#
# Epoch 191: val_accuracy did not improve from 0.47727
#
# Epoch 192: val_accuracy did not improve from 0.47727
#
# Epoch 193: val_accuracy did not improve from 0.47727
#
# Epoch 194: val_accuracy did not improve from 0.47727
#
# Epoch 195: val_accuracy did not improve from 0.47727
#
# Epoch 196: val_accuracy did not improve from 0.47727
#
# Epoch 197: val_accuracy did not improve from 0.47727
#
# Epoch 198: val_accuracy did not improve from 0.47727
#
# Epoch 199: val_accuracy did not improve from 0.47727
#
# Epoch 200: val_accuracy did not improve from 0.47727
# #################################################
